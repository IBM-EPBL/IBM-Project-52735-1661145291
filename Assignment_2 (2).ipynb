# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# 3.Visualization

# %% [markdown]
# Univariate Analysis

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts HasCrCard  IsActiveMember  \
# 0       2       0.00              1       yes               1
# 1       1   83807.86              1        no               1
# 2       8  159660.80              3       yes               0
# 3       1       0.00              2        no               0
# 4       2  125510.82              1       yes               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df['CreditScore'].mean()
# Out:
# 650.5288

# %%
df['CreditScore'].median()
# Out:
# 652.0

# %%
df['CreditScore'].std()
# Out:
# 96.65329873613035

# %%
df['CreditScore'].value_counts()
# Out:
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: CreditScore, Length: 460, dtype: int64

# %%
sns.boxplot(df['Exited'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.hist(column='Exited')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f30069e1110>]],
#       dtype=object)

# %%
sns.kdeplot(df['Exited'])

# %% [markdown]
# Bi-Variate analysis

# %%
plt.scatter(df.IsActiveMember,df.Exited)
plt.title('IsActiveMemer.Exited')
plt.xlabel('IsActiveMenber')
plt.ylabel('Exited')
# Out:
# Text(0, 0.5, 'Exited')

# %%
df.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  IsActiveMember  EstimatedSalary  \
# RowNumber       -0.009067       0.007246        0.012044        -0.005988
# ...

# %% [markdown]
# Multi-Variate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# 4.descripe statistics

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail(4)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# 5.Missing values

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# 6.outliers and replace the outliers

# %%
numeric_col=['Surname','RowNumber']
categorical_col=['HasCrCard']

# %%
sns.boxplot(df['Exited'],data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 7.Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count

# %%
le=LabelEncoder

# %%
df['HasCrCard'].unique()
# Out:
# array([1, 0])

# %%
count(df['HasCrCard'])
# Out:
# Counter({1: 7055, 0: 2945})

# %%
count(df['HasCrCard'])
# Out:
# Counter({1: 7055, 0: 2945})

# %%
count(df['HasCrCard'])
# Out:
# Counter({1: 7055, 0: 2945})

# %%
df['HasCrCard']=df['HasCrCard'].replace([1,0],["yes","no"])

# %%
count(df['HasCrCard'])
# Out:
# Counter({'yes': 7055, 'no': 2945})

# %%
df1=pd.read_csv('/content/Churn_Modelling.csv')

# %%
df1['HasCrCard']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    1
# Name: HasCrCard, Length: 10000, dtype: int64

# %%
HasCrCard=pd.get_dummies(df1['HasCrCard'],prefix='HasCrCard_')

# %%
HasCrCard
# Out:
#       HasCrCard__0  HasCrCard__1
# 0                0             1
# 1                1             0
# 2                0             1
# 3                1             0
# 4                0             1
# ...            ...           ...
# 9995             0             1
# 9996             0             1
# 9997             1             0
# 9998             0             1
# 9999             0             1
#
# [10000 rows x 2 columns]

# %% [markdown]
# 8.Split the data into dependent and independent variables

# %%
x=df.iloc[:,9:-1]
y=df.iloc[:,0:9]

# %%
x
# Out:
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0                 1          1               1        101348.88
# 1                 1          0               1        112542.58
# 2                 3          1               0        113931.57
# 3                 2          0               0         93826.63
# 4                 1          1               1         79084.10
# ...             ...        ...             ...              ...
# 9995              2          1               0         96270.64
# 9996              1          1               1        101699.77
# 9997              1          0               1         42085.58
# 9998              2          1               0         92888.52
# 9999              1          1               0         38190.78
#
# [10000 rows x 4 columns]

# %%
y
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance
# 0          2       0.00
# ...

# %% [markdown]
# 9.scale the variables

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
st=StandardScaler()
nm=MinMaxScaler()

# %% [markdown]
# 10.Split the data into training and testiing

# %%
x=df.iloc[:,9:-1]
y=df.iloc[:,0:9]

# %%
x
# Out:
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# ...

# %%
y
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance
# 0          2       0.00
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.05,random_state=10)

# %%
xtrain
# Out:
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 3647              1          0               1        102391.06
# 8338              1          1               1        139494.75
# 6872              2          1               1          3025.49
# 3535              1          1               1         48233.75
# 2352              1          1               1        145134.49
# ...             ...        ...             ...              ...
# 9372              1          0               1        174225.88
# 7291              1          1               0        111622.76
# 1344              2          1               0         91560.63
# 7293              1          1               0         57029.66
# 1289              1          1               0          1285.81
#
# [9500 rows x 4 columns]

# %%
xtest
# Out:
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 937               1          0               1        171096.20
# 9355              1          1               0        167030.51
# 2293              1          1               0        197804.00
# 192               2          0               0        114996.43
# 8675              1          1               0        112777.38
# ...             ...        ...             ...              ...
# 5234              1          1               0        196622.28
# 5733              1          1               0        152107.93
# 7104              1          0               1        135227.23
# 1067              2          1               0        128815.33
# 931               2          1               1         34338.21
#
# [500 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
st=StandardScaler()
nm=MinMaxScaler()

# %%
s_xtrain=st.fit_transform(xtrain)
s_xtrain
# Out:
# array([[-0.91426913, -1.55041863,  0.96706826,  0.0398363 ],
#        [-0.91426913,  0.64498709,  0.96706826,  0.68508126],
#        [ 0.80871376,  0.64498709,  0.96706826, -1.68816252],
#        ...,
#        [ 0.80871376,  0.64498709, -1.03405317, -0.14850831],
#        [-0.91426913,  0.64498709, -1.03405317, -0.74901285],
#        [-0.91426913,  0.64498709, -1.03405317, -1.71841611]])

# %%
s_xtest=st.transform(xtest)
s_xtest
# Out:
# array([[-0.91426913, -1.55041863,  0.96706826,  1.23464051],
#        [-0.91426913,  0.64498709, -1.03405317,  1.16393687],
#        [-0.91426913,  0.64498709, -1.03405317,  1.69909764],
#        ...,
#        [-0.91426913, -1.55041863,  0.96706826,  0.61086773],
#        [ 0.80871376,  0.64498709, -1.03405317,  0.49936275],
#        [ 0.80871376,  0.64498709,  0.96706826, -1.14362438]])

# %%
n_xtrain=nm.fit_transform(xtrain)
n_xtrain
# Out:
# array([[0.        , 0.        , 1.        , 0.51194629],
#        [0.        , 1.        , 1.        , 0.69748246],
#        [0.33333333, 1.        , 1.        , 0.01507099],
#        ...,
#        [0.33333333, 1.        , 0.        , 0.45778897],
#        [0.        , 1.        , 0.        , 0.28511763],
#        [0.        , 1.        , 0.        , 0.00637176]])

# %%
n_xtest=nm.transform(xtest)
n_xtest
# Out:
# array([[0.        , 0.        , 1.        , 0.8555048 ],
#        [0.        , 1.        , 0.        , 0.83517441],
#        [0.        , 1.        , 0.        , 0.98905655],
#        ...,
#        [0.        , 0.        , 1.        , 0.67614282],
#        [0.33333333, 1.        , 0.        , 0.64408026],
#        [0.33333333, 1.        , 1.        , 0.17164954]])
